# %% [markdown]
# ## Exploratory Data Analysis for Image Dataset
# For starters, we will be experiencing an EDA for finding the best, simple features from our image dataset.
# Remember, our aim is to create an image classification model, and deploy it to production.
# Let's try to create an ML model that has a good performance and resource friendly.
#
# ### Preparation
# - Have a "hungry for learning" mentality
# - Install prerequisites dependencies
#   - pandas
#   - numpy
#   - matplotlib
#   - opencv-python
#   - scikit-image
#   - scikit-learn
# - Download the required dataset
#   - Books and Non Books Dataset

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.feature import hog, local_binary_pattern
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Preparing Raw Image Folders for EDA
# Download link:

# %%
BOOK_DATASET_FOLDER = "data/books"
NONBOOK_DATASET_FOLDER = "data/non_books"

# %%
def load_image(path):
    # Load the image
    image = cv2.imread(path)

    # Display the image
    plt.imshow(image)
    plt.title('Original Image')
    plt.show()

    return image

image = load_image(f'{NONBOOK_DATASET_FOLDER}/image_1.jpg')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# ### Understanding the Image Properties
# This is a very important activities before we use image data as our ML dataset.
# As we have explained, ML Model cannot understand image.
# Image need to be transformed into floating number so it could be learned by ML Model

# %%
# Get image properties
dimensions = image.shape
height, width, channels = dimensions

print(f'Dimensions: {dimensions}')
print(f'Height: {height}, Width: {width}, Channels: {channels}')
# Out:
# Dimensions: (825, 550, 3)
# Height: 825, Width: 550, Channels: 3

# %%
color = ('b', 'g', 'r')
for i, col in enumerate(color):
    histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram, color=col)
    plt.xlim([0, 256])

plt.title('Color Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()
## Salah satu faktor yang dapat mendeteksi buku dengan non buku

# %%
edges = cv2.Canny(image, 100, 200)

plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
plt.show()
## Salah satu faktor yang dapat mendeteksi buku dengan non buku

# %%
# Initiate ORB detector
orb = cv2.ORB_create()

# Find the keypoints with ORB
keypoints, descriptors = orb.detectAndCompute(image, None)

# Draw only keypoints location, not size and orientation
image_with_keypoints = cv2.drawKeypoints(image_rgb, keypoints, None, color=(0, 255, 0), flags=0)

plt.imshow(image_with_keypoints)
plt.title('ORB Keypoints')
plt.show()
## Salah satu faktor yang dapat mendeteksi buku dengan non buku

# %%
# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply a binary threshold to get a binary image
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

plt.imshow(thresh, cmap='gray')
plt.title('Binary Thresholding')
plt.show()

# %%
# Parameters for LBP Local Binary Pattern
radius = 3
n_points = 8 * radius

# Apply LBP
lbp = local_binary_pattern(gray, n_points, radius, method='uniform')

plt.imshow(lbp, cmap='gray')
plt.title('Local Binary Pattern')
plt.show()

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the original image
image_contours = image_rgb.copy()
cv2.drawContours(image_contours, contours, -1, (0, 255, 0), 3)

plt.imshow(image_contours)
plt.title('Contours')
plt.show()

# %%
# Load the image
image_path = f'{BOOK_DATASET_FOLDER}/image_4.jpg'
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Thresholding to create a binary image
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# Draw bounding box, convex hull, and enclosing circle
image_contours = image_rgb.copy()

for contour in contours:
    # Bounding box
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(image_contours, (x, y), (x+w, y+h), (0, 255, 0), 2)

    # Convex hull
    hull = cv2.convexHull(contour)
    cv2.drawContours(image_contours, [hull], 0, (255, 0, 0), 2)

    # Enclosing circle
    (x, y), radius = cv2.minEnclosingCircle(contour)
    center = (int(x), int(y))
    radius = int(radius)
    cv2.circle(image_contours, center, radius, (0, 0, 255), 2)

# Display the image with bounding boxes, convex hulls, and enclosing circles
plt.imshow(image_contours)
plt.title('Contours with Bounding Boxes, Convex Hulls, and Enclosing Circles')
plt.axis('off')
plt.show()
#Terlihat dari whitespaces yang terlihat antara buku dengan nonbuku

# %%
for contour in contours:
    area = cv2.contourArea(contour)
    perimeter = cv2.arcLength(contour, True)
    print(f'Contour Area: {area}, Perimeter: {perimeter}')
# Out:
# Contour Area: 0.0, Perimeter: 2.8284270763397217
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 5.656854152679443
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 164.5, Perimeter: 100.81118202209473
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 1.0, Perimeter: 9.656854152679443
# Contour Area: 1462.5, Perimeter: 293.32084798812866
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 3.0, Perimeter: 84.91168737411499
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 0.0, Perimeter: 11.656854152679443
# Contour Area: 7.0, Perimeter: 10.828427076339722
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.5, Perimeter: 3.414213538169861
# Contour Area: 0.5, Perimeter: 3.414213538169861
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 1.5, Perimeter: 13.071067690849304
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 1.5, Perimeter: 13.071067690849304
# Contour Area: 0.5, Perimeter: 13.071067690849304
# Contour Area: 5.5, Perimeter: 9.41421353816986
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 3.0, Perimeter: 11.656854152679443
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 1.0, Perimeter: 11.656854152679443
# Contour Area: 5.0, Perimeter: 8.828427076339722
# Contour Area: 2.0, Perimeter: 8.828427076339722
# Contour Area: 8.5, Perimeter: 11.071067690849304
# Contour Area: 7.0, Perimeter: 9.656854152679443
# Contour Area: 0.5, Perimeter: 14.242640614509583
# Contour Area: 3.5, Perimeter: 11.071067690849304
# Contour Area: 0.5, Perimeter: 15.071067690849304
# Contour Area: 0.0, Perimeter: 14.485281229019165
# Contour Area: 8.5, Perimeter: 11.071067690849304
# Contour Area: 7.0, Perimeter: 9.656854152679443
# Contour Area: 1.5, Perimeter: 5.414213538169861
# Contour Area: 0.5, Perimeter: 15.071067690849304
# Contour Area: 8.5, Perimeter: 11.071067690849304
# Contour Area: 5.5, Perimeter: 9.071067690849304
# Contour Area: 1.0, Perimeter: 15.656854152679443
# Contour Area: 2.0, Perimeter: 12.485281229019165
# Contour Area: 1.0, Perimeter: 4.828427076339722
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 2.0, Perimeter: 9.656854152679443
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 2.5, Perimeter: 10.242640614509583
# Contour Area: 2.5, Perimeter: 9.071067690849304
# Contour Area: 2.0, Perimeter: 6.828427076339722
# Contour Area: 2.0, Perimeter: 13.656854152679443
# Contour Area: 2.0, Perimeter: 8.828427076339722
# Contour Area: 0.5, Perimeter: 12.242640614509583
# Contour Area: 4.0, Perimeter: 9.656854152679443
# Contour Area: 0.0, Perimeter: 17.313708305358887
# Contour Area: 0.5, Perimeter: 7.414213538169861
# Contour Area: 2.0, Perimeter: 6.828427076339722
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 1.0, Perimeter: 4.828427076339722
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 4.0, Perimeter: 15.313708305358887
# Contour Area: 1.5, Perimeter: 15.071067690849304
# Contour Area: 3.5, Perimeter: 10.242640614509583
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 0.5, Perimeter: 12.242640614509583
# Contour Area: 3.0, Perimeter: 10.485281229019165
# Contour Area: 2.5, Perimeter: 7.414213538169861
# Contour Area: 2.0, Perimeter: 11.656854152679443
# Contour Area: 0.5, Perimeter: 13.071067690849304
# Contour Area: 7.5, Perimeter: 11.071067690849304
# Contour Area: 7.0, Perimeter: 10.485281229019165
# Contour Area: 0.0, Perimeter: 7.656854152679443
# Contour Area: 0.5, Perimeter: 10.242640614509583
# Contour Area: 1.0, Perimeter: 8.828427076339722
# Contour Area: 1.0, Perimeter: 11.656854152679443
# Contour Area: 1.0, Perimeter: 8.828427076339722
# Contour Area: 2.0, Perimeter: 9.656854152679443
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 51.5, Perimeter: 108.18376553058624
# Contour Area: 29.5, Perimeter: 58.24264061450958
# Contour Area: 43.0, Perimeter: 91.59797894954681
# Contour Area: 62.0, Perimeter: 93.65685415267944
# Contour Area: 33.5, Perimeter: 57.55634891986847
# Contour Area: 213.0, Perimeter: 60.14213526248932
# Contour Area: 70.5, Perimeter: 33.899494647979736
# Contour Area: 56.5, Perimeter: 31.071067690849304
# Contour Area: 227.0, Perimeter: 58.28427052497864
# Contour Area: 169.0, Perimeter: 49.455843687057495
# Contour Area: 111.0, Perimeter: 54.485281229019165
# Contour Area: 63.0, Perimeter: 34.97056245803833
# Contour Area: 133.0, Perimeter: 68.97056245803833
# Contour Area: 72.0, Perimeter: 34.485281229019165
# Contour Area: 86.0, Perimeter: 61.11269783973694
# Contour Area: 25.0, Perimeter: 19.313708186149597
# Contour Area: 50.5, Perimeter: 85.21320307254791
# Contour Area: 51.5, Perimeter: 109.01219236850739
# Contour Area: 204.0, Perimeter: 143.74011552333832
# Contour Area: 208.5, Perimeter: 141.9827550649643
# Contour Area: 108.5, Perimeter: 89.98275518417358
# Contour Area: 100.5, Perimeter: 83.41421353816986
# Contour Area: 114.0, Perimeter: 108.48528122901917
# Contour Area: 203.5, Perimeter: 144.4680371284485
# Contour Area: 225.0, Perimeter: 96.08326029777527
# Contour Area: 56.0, Perimeter: 30.14213538169861
# Contour Area: 66.0, Perimeter: 50.0
# Contour Area: 100.5, Perimeter: 83.41421353816986
# Contour Area: 102.0, Perimeter: 84.82842707633972
# Contour Area: 65.5, Perimeter: 49.41421353816986
# Contour Area: 187.5, Perimeter: 165.63960874080658
# Contour Area: 4.5, Perimeter: 15.071067690849304
# Contour Area: 1.5, Perimeter: 7.414213538169861
# Contour Area: 16.5, Perimeter: 22.727921724319458
# Contour Area: 7.5, Perimeter: 11.071067690849304
# Contour Area: 21.5, Perimeter: 19.899494767189026
# Contour Area: 15.5, Perimeter: 15.899494767189026
# Contour Area: 6.5, Perimeter: 27.899494767189026
# Contour Area: 7.5, Perimeter: 24.727921724319458
# Contour Area: 24.5, Perimeter: 19.899494767189026
# Contour Area: 17.5, Perimeter: 16.727921724319458
# Contour Area: 22.5, Perimeter: 19.899494767189026
# Contour Area: 13.5, Perimeter: 13.899494767189026
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 6.828427076339722
# Contour Area: 0.0, Perimeter: 6.828427076339722
# Contour Area: 0.0, Perimeter: 11.656854152679443
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 4.0
# Contour Area: 1.0, Perimeter: 9.656854152679443
# Contour Area: 2.0, Perimeter: 6.828427076339722
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 6.0
# Contour Area: 0.5, Perimeter: 7.414213538169861
# Contour Area: 0.0, Perimeter: 6.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 1.0, Perimeter: 9.656854152679443
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.5, Perimeter: 7.414213538169861
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.5, Perimeter: 7.414213538169861
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 2.0, Perimeter: 8.828427076339722
# Contour Area: 0.5, Perimeter: 3.414213538169861
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 0.5, Perimeter: 11.071067690849304
# Contour Area: 1.5, Perimeter: 10.242640614509583
# Contour Area: 2.5, Perimeter: 15.899494767189026
# Contour Area: 0.5, Perimeter: 8.242640614509583
# Contour Area: 0.0, Perimeter: 6.828427076339722
# Contour Area: 0.5, Perimeter: 27.55634891986847
# Contour Area: 1.5, Perimeter: 11.071067690849304
# Contour Area: 5.5, Perimeter: 27.55634891986847
# Contour Area: 1.0, Perimeter: 6.828427076339722
# Contour Area: 1.0, Perimeter: 21.313708186149597
# Contour Area: 0.0, Perimeter: 8.0
# Contour Area: 1.0, Perimeter: 10.485281229019165
# Contour Area: 0.0, Perimeter: 7.656854152679443
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 2.8284270763397217
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 2.8284270763397217
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 0.0
# Contour Area: 0.0, Perimeter: 4.828427076339722
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 0.0, Perimeter: 2.0
# Contour Area: 1.5, Perimeter: 9.071067690849304
# Contour Area: 2.0, Perimeter: 14.828427076339722
# Contour Area: 2.5, Perimeter: 16.242640614509583
# Contour Area: 9.0, Perimeter: 30.97056245803833
# Contour Area: 1.0, Perimeter: 8.828427076339722
# Contour Area: 20.0, Perimeter: 24.485281229019165
# Contour Area: 5.5, Perimeter: 9.071067690849304
# Contour Area: 9.5, Perimeter: 26.242640614509583
# Contour Area: 11.5, Perimeter: 25.071067690849304
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 15.0, Perimeter: 31.313708305358887
# Contour Area: 4.0, Perimeter: 7.656854152679443
# Contour Area: 5.0, Perimeter: 16.82842707633972
# Contour Area: 21.0, Perimeter: 20.485281229019165
# Contour Area: 6.0, Perimeter: 9.656854152679443
# Contour Area: 6.0, Perimeter: 9.656854152679443
# Contour Area: 9.5, Perimeter: 26.242640614509583
# Contour Area: 2.0, Perimeter: 5.656854152679443
# Contour Area: 24.0, Perimeter: 18.82842707633972
# Contour Area: 8.0, Perimeter: 11.656854152679443
# Contour Area: 4.0, Perimeter: 7.656854152679443
# Contour Area: 15.5, Perimeter: 28.727921843528748
# Contour Area: 4.0, Perimeter: 7.656854152679443
# Contour Area: 8.5, Perimeter: 27.071067690849304
# Contour Area: 7.0, Perimeter: 17.656854152679443
# Contour Area: 8.5, Perimeter: 22.727921843528748
# Contour Area: 19.5, Perimeter: 23.071067690849304
# Contour Area: 8.5, Perimeter: 11.071067690849304
# Contour Area: 28.5, Perimeter: 19.899494767189026
# Contour Area: 18.5, Perimeter: 16.727921843528748
# Contour Area: 5.0, Perimeter: 17.313708186149597
# Contour Area: 12.5, Perimeter: 36.38477599620819
# Contour Area: 13.5, Perimeter: 25.071067571640015
# Contour Area: 4.0, Perimeter: 7.656854152679443
# Contour Area: 8.0, Perimeter: 27.313708305358887

# %%
radius = 3
n_points = 8 * radius
lbp = local_binary_pattern(gray, n_points, radius, method='uniform')

plt.imshow(lbp, cmap='gray')
plt.title('Local Binary Pattern')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Image Data Feature Extraction

# %%
# Function to read and preprocess the image
def read_and_preprocess_image(image_path, target_size=(128, 128)):
    """
    Read and preprocess the image: resize, convert to RGB and grayscale.

    :param image_path: Path to the image file.
    :param target_size: Desired size to resize the image to (width, height).
    :return: Tuple containing the resized image, RGB image, and grayscale image.
    """
    # Read the image from the given path
    image = cv2.imread(image_path)

    # Resize the image to the target size
    image_resized = cv2.resize(image, target_size, interpolation=cv2.INTER_AREA)

    # Convert the resized image to RGB
    image_rgb = cv2.cvtColor(image_resized, cv2.COLOR_BGR2RGB)

    # Convert the resized image to grayscale
    gray = cv2.cvtColor(image_resized, cv2.COLOR_BGR2GRAY)

    return image_resized, image_rgb, gray

# Function to extract HOG features
def extract_hog_features(image):
    hog_features, _ = hog(image, visualize=True, pixels_per_cell=(8, 8), cells_per_block=(2, 2), block_norm='L2-Hys')
    return hog_features

# Function to extract color histogram features
def extract_color_histogram(image):
    color_features = []
    for i, col in enumerate(('b', 'g', 'r')):
        histogram = cv2.calcHist([image], [i], None, [256], [0, 256])
        histogram = cv2.normalize(histogram, histogram).flatten()
        color_features.extend(histogram)
    return np.array(color_features)

# Function to extract LBP features
def extract_lbp_features(image):
    radius = 3
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

# Function to extract shape features (area and perimeter of largest contour)
def extract_shape_features(image):
    ret, thresh = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        area = cv2.contourArea(largest_contour)
        perimeter = cv2.arcLength(largest_contour, True)
        return np.array([area, perimeter])
    else:
        return np.array([0, 0])

# Main function to extract all features and create a feature vector
def extract_features(image_path):
    image, image_rgb, gray = read_and_preprocess_image(image_path)

    hog_features = extract_hog_features(gray)
    color_histogram = extract_color_histogram(image_rgb)
    lbp_features = extract_lbp_features(gray)
    shape_features = extract_shape_features(gray)

    features = np.concatenate([hog_features, color_histogram, lbp_features, shape_features])
    return features

# %%
import os
import tqdm
from tqdm import tqdm

NUMBER_OF_DATA = 500

all_data = []

nonbook_image_paths = [os.path.join(NONBOOK_DATASET_FOLDER, f) for f in os.listdir(NONBOOK_DATASET_FOLDER)[:NUMBER_OF_DATA] if f.endswith(('.jpg', '.jpeg', '.png'))]
book_image_paths = [os.path.join(BOOK_DATASET_FOLDER, f) for f in os.listdir(BOOK_DATASET_FOLDER)[:NUMBER_OF_DATA] if f.endswith(('.jpg', '.jpeg', '.png'))]

all_data = nonbook_image_paths + book_image_paths

len(all_data)
# Out:
# 1000

# %%
# Extract features from each image
feature_list = []

for image_path in tqdm(all_data):
    features = extract_features(image_path)
    feature_list.append(features)

# Convert the list of feature vectors into a DataFrame
features_matrix = pd.DataFrame(feature_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:33<00:00, 30.08it/s]

# %%
features_matrix
# Out:
#          0         1         2         3         4         5         6     \
# 0    0.035325  0.024379  0.039598  0.018615  0.697853  0.021496  0.000000
# 1    0.061985  0.026517  0.018429  0.046324  0.300442  0.300442  0.238482
# 2    0.097807  0.068205  0.140376  0.263757  0.175921  0.038417  0.064812
# 3    0.210183  0.057576  0.147908  0.294355  0.294355  0.000000  0.011292
# 4    0.281892  0.088989  0.114617  0.067637  0.251092  0.068656  0.215914
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.277148  0.158458  0.178174  0.152932  0.076832  0.112259  0.115429
# 996  0.259728  0.265093  0.207715  0.085662  0.256820  0.000000  0.080660
# 997  0.266725  0.000000  0.000000  0.000000  0.003031  0.000000  0.003643
# 998  0.171820  0.185190  0.142651  0.254423  0.254423  0.254423  0.242240
# 999  0.228218  0.028019  0.145209  0.136882  0.169950  0.228218  0.220527
#
#          7         8         9     ...      8886      8887      8888  \
# 0    0.000000  0.004192  0.007953  ...  0.010803  0.014099  0.012207
# 1    0.000000  0.000000  0.059601  ...  0.008667  0.010620  0.010315
# 2    0.016589  0.013065  0.049462  ...  0.008545  0.010559  0.011169
# 3    0.000000  0.000000  0.178246  ...  0.009949  0.010193  0.011292
# 4    0.179549  0.135849  0.196900  ...  0.011963  0.012085  0.011902
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.050143  0.251833  0.277148  ...  0.013672  0.012390  0.014343
# 996  0.139908  0.157845  0.265093  ...  0.018982  0.020874  0.018433
# 997  0.133776  0.149786  0.373264  ...  0.014526  0.015869  0.017456
# 998  0.101466  0.074445  0.182763  ...  0.014587  0.013123  0.014587
# 999  0.164566  0.222852  0.084535  ...  0.012878  0.012573  0.011780
#
#          8889      8890      8891      8892      8893     8894         8895
# 0    0.012024  0.016541  0.018127  0.045898  0.329651   8319.0  1187.068102
# 1    0.014832  0.018066  0.038025  0.049377  0.501160   4390.0   910.014280
# 2    0.017273  0.025818  0.032166  0.049316  0.492310   8742.5   689.404109
# 3    0.016907  0.020752  0.026062  0.042236  0.433594   4977.5   778.374671
# 4    0.015747  0.019531  0.021484  0.120361  0.301941   5453.0  1140.406196
# ..        ...       ...       ...       ...       ...      ...          ...
# 995  0.017883  0.020813  0.028870  0.049561  0.435181   3347.5   467.688379
# 996  0.020142  0.019043  0.019470  0.033325  0.373047    124.0    55.455844
# 997  0.018066  0.020264  0.027039  0.048157  0.346497  13225.0  1457.602154
# 998  0.017090  0.021729  0.029968  0.058899  0.383423   1738.5   661.487369
# 999  0.016663  0.018188  0.026917  0.043091  0.441406  10053.5   863.913775
#
# [1000 rows x 8896 columns]

# %%
from sklearn.decomposition import PCA

# Normalize the feature matrix
scaler = StandardScaler()
normalized_features_matrix = scaler.fit_transform(features_matrix)

# Apply PCA for dimensionality reduction, preserving 95% of the variance
pca = PCA(n_components=50)  # Use percentage of variance explained
pca_features_matrix = pca.fit_transform(features_matrix)
print(pca_features_matrix)
# Out:
# [[ 7.41138999e+02  4.26662877e+02  7.37318424e-02 ... -1.69277493e-01
#    2.59036112e-01 -6.96341520e-01]
#  [-3.19305254e+03  2.37091119e+02 -2.29122506e-01 ...  1.65784732e+00
#   -1.60096932e-01  7.02318715e-01]
#  [ 1.15346180e+03 -8.02952536e+01 -1.74317404e+00 ... -8.11290178e-01
#   -2.34951208e-01  2.65385461e-01]
#  ...
#  [ 5.65194351e+03  5.87976626e+02  2.76494670e+00 ...  2.99574599e-01
#    4.32304055e-01 -3.76237050e-01]
#  [-5.84942552e+03  4.76121545e+01  2.30844585e+00 ... -1.99629585e-02
#   -9.13081018e-01 -1.29274490e+00]
#  [ 2.46801997e+03  6.49988169e+01  6.22017727e-01 ... -1.33757236e-01
#    8.05856423e-01  2.48308367e-01]]

# %%
pca_features_matrix.shape
# Out:
# (1000, 50)

# %% [markdown]
# ## Model Development for Book Image Classification
# It's time to create an ML Classification Model for detecting a non-book image for Yanto.
# Here we will be using the image features that has been generated in the previous section and create a
# simple ML Classification Model.
# Let's see how it goes
#
# ### ML Algorithms Used in this Section
# - LogisticRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Split the dataset into training and testing sets

# %%
labels = [0 if 'non_books' in path else 1 for path in all_data]

X_train, X_test, y_train, y_test = train_test_split(pca_features_matrix, labels, test_size=0.2, random_state=42)

# %% [markdown]
# ### Train and Evaluate some ML Model

# %%
import mlflow
from mlflow.models import infer_signature
import mlflow.sklearn


# Set MLflow tracking URI dan eksperimen
mlflow.set_tracking_uri('http://localhost:8080')
mlflow.set_experiment('book-classification')

# Definisikan model-model yang akan dibandingkan
models = {
    "Logistic Regression": LogisticRegression(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "SVM": SVC(kernel='linear', random_state=42)
}

# Loop melalui setiap model
for model_name, model in models.items():
    with mlflow.start_run(run_name=model_name):
        model.fit(X_train, y_train)
        signature = infer_signature(X_test, model.predict(X_test))

        model_info = mlflow.sklearn.log_model(
            sk_model=model, artifact_path="model", signature=signature
        )

        # Make predictions
        y_pred = model.predict(X_test)

        # Calculate metrics
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, output_dict=True)

        # Log metrics
        mlflow.log_metric("accuracy", accuracy)

        for key, value in class_report.items():
            if isinstance(value, dict):
                for sub_key, sub_value in value.items():
                    mlflow.log_metric(f"{key}_{sub_key}", sub_value)
            else:
                mlflow.log_metric(key, value)

        # Print metrics
        print(f"Model: {model_name}")
        print("Accuracy:", accuracy)
        print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 2024/05/20 00:45:47 WARNING mlflow.utils.requirements_utils: Found lz4 version (3.1.3+dfsg) contains a local version label (+dfsg). MLflow logged a pip requirement for this package as 'lz4==3.1.3' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# Model: Logistic Regression
# Accuracy: 0.98
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        96
#            1       0.98      0.98      0.98       104
#
#     accuracy                           0.98       200
#    macro avg       0.98      0.98      0.98       200
# weighted avg       0.98      0.98      0.98       200
# 2024/05/20 00:45:48 WARNING mlflow.utils.requirements_utils: Found lz4 version (3.1.3+dfsg) contains a local version label (+dfsg). MLflow logged a pip requirement for this package as 'lz4==3.1.3' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# Model: Random Forest
# Accuracy: 0.965
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        96
#            1       0.96      0.97      0.97       104
#
#     accuracy                           0.96       200
#    macro avg       0.97      0.96      0.96       200
# weighted avg       0.97      0.96      0.96       200
# 2024/05/20 00:47:34 WARNING mlflow.utils.requirements_utils: Found lz4 version (3.1.3+dfsg) contains a local version label (+dfsg). MLflow logged a pip requirement for this package as 'lz4==3.1.3' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# Model: SVM
# Accuracy: 0.965
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        96
#            1       0.98      0.95      0.97       104
#
#     accuracy                           0.96       200
#    macro avg       0.96      0.97      0.96       200
# weighted avg       0.97      0.96      0.97       200

# %% [markdown]
# ### Testing the ML Model

# %%
# Function to predict the class of a new image
def predict_image(image_path, model, scaler, pca):
    features = extract_features(image_path)
    features = features.reshape(1, -1)
    features_normalized = scaler.transform(features)
    features_pca = pca.transform(features_normalized)

    prediction = model.predict(features_pca)

    if prediction[0] == 0:
        return 'Non-Book'
    else:
        return 'Book'


sklearn_pyfunc = mlflow.pyfunc.load_model(model_uri=model_info.model_uri)


# Example usage for prediction on a new image
new_image_path = f'{NONBOOK_DATASET_FOLDER}/image_511.jpg'
predicted_class = predict_image(new_image_path, sklearn_pyfunc, scaler, pca)
load_image(new_image_path)
print("This is a :", predicted_class)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading artifacts', max=9.0, style=ProgressStyle(desc…
# This is a : Non-Book

# %% [markdown]
# ## Model Deployment for Book Image Classification
# We almost reach our end of the journey, now it's time to create deploy our ML Model to that it could be integrated with another system.
#
#
# ### Preparation
# - Install prerequisites dependencies
#   - mlflow

# %%
# run the deployment script
# !bash run.sh
# Out:
# Downloading artifacts: 100%|█████████████████████| 1/1 [00:00<00:00, 960.67it/s]
# 2024/05/20 00:52:37 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# Downloading artifacts: 100%|█████████████████████| 9/9 [00:00<00:00, 354.72it/s]
# 2024/05/20 00:52:37 INFO mlflow.pyfunc.backend: === Running command 'exec gunicorn --timeout=60 -b 127.0.0.1:5000 -w 1 ${GUNICORN_CMD_ARGS} -- mlflow.pyfunc.scoring_server.wsgi:app'
# [2024-05-20 00:52:37 +0700] [174928] [INFO] Starting gunicorn 22.0.0
# [2024-05-20 00:52:37 +0700] [174928] [INFO] Listening at: http://127.0.0.1:5000 (174928)
# [2024-05-20 00:52:37 +0700] [174928] [INFO] Using worker: sync
# [2024-05-20 00:52:37 +0700] [174930] [INFO] Booting worker with pid: 174930

# %%
# Get the features of the new image

# Function to predict the class of a new image
def preprocessing(image_path, scaler, pca):
    features = extract_features(image_path)
    features = features.reshape(1, -1)
    features_normalized = scaler.transform(features)
    features_pca = pca.transform(features_normalized)
    return features_pca

features = preprocessing(new_image_path, scaler, pca)
features

# %%
import requests
import json

headers = {
    'Content-Type': 'application/json;',
}

json_data = json.dumps({
    'inputs': features.tolist()
})

response = requests.post('http://127.0.0.1:5000/invocations', headers=headers, data=json_data)

# %%
response.content

# %%
# Out:
# <Response [404]>
